# %%
import json
import pandas as pd
import numpy as np
from pprint import pprint
import random
from collections import Counter
import os

# %%
def get_arguments(fname):
    with open(fname, "r") as f:
        arguments = f.read()
    arguments = json.loads(arguments)
    return arguments

# %%
def extract_id_from_imgname(s):
    """From the image ID from split URL"""
    assert s, "Got empty imgname!"
    img_no_ext = s.rsplit(".", maxsplit=1)[0]
    
    id = ""
    num_found = False
    for ch in img_no_ext[::-1]:
        if ch.isdigit():
            id += ch
            num_found = True
        elif num_found:
            break
    assert num_found, f"The imgname {s} had no numbers!"
    
    id = int(id[::-1])
    return id

def get_id_url_mapping(fname):
    """Get the Dict used for replacing an image ID with the URL which shows the corresponding SVG"""
    id_to_url = dict()
    with open(fname, "r") as infile:
        for url in infile:
            url = url.strip()
            if not url:
                continue
            id = extract_id_from_imgname(url.rsplit("/", maxsplit=1)[-1])
            id_to_url[id]= url
    return id_to_url

# %%
def arguments_to_df(arguments, id_to_url):
    df = pd.DataFrame(arguments.items(), columns=["dims","args"]).explode("args")
    df[["dim1", "dim2"]] = df["dims"].str.split(",", expand=True)
    df[["arg1", "arg2"]] = df["args"].apply(pd.Series)
    for i in [1,2]:
        df[f"url{i}"] = df[f"arg{i}"].apply(lambda x: id_to_url[x["id"]])
    df = df[["dim1", "dim2", "url1", "url2"]]
    return df

# %%
def add_control_rows(df, controls_dict, repeats):
    """
    Insert control rows to avoid unreliable annotators. 
    Will always be paired with an argument from the baseline.
    """
    assert "baseline" not in df["dim2"], "Currently, this function only takes the dataframe that is not column-shuffled!"
    df = df.copy()

    n_samples = len(controls_dict)*repeats
    dim1_unique_subset = df[(df["dim1"]=="baseline")].drop_duplicates(subset=["dim1","url1"])
    samples1 = dim1_unique_subset.sample(len(dim1_unique_subset), replace=False) #Make sure all are seen before duplicates
    if len(samples1) == n_samples:
        samples = samples1
    else:
        samples2 = dim1_unique_subset.sample(n_samples-len(dim1_unique_subset), replace=True)
        samples = pd.concat([samples1, samples2])

    # Overwrite dim2 with controls (columns are shuffled later, in another function)
    dim2url2_1 = [(f"control{key}", url) for key,url in controls_dict.items()] #Make sure all are seen before duplicates
    dim2url2_2 = [(f"control{key}", url) for key,url in controls_dict.items()]*(repeats-1)
    random.shuffle(dim2url2_1) #Inplace
    random.shuffle(dim2url2_2) #Inplace
    dim2, url2 = list(zip(*dim2url2_1+dim2url2_2))
    samples["dim2"] = dim2
    samples["url2"] = url2

    df = pd.concat([df, samples])
    return df

# %%
def shuffle_columns(df):
    """Remove bias by shuffling order of arguments. E.g., avoid one dimension always being displayed first."""
    df = df.copy()
    df["swapped"] = None
    for i in range(len(df)):
        if random.random() < 0.5: #50% chance
            df["dim1"].iloc[i], df["dim2"].iloc[i] = df["dim2"].iloc[i], df["dim1"].iloc[i] #Swap 1 and 2
            df["url1"].iloc[i], df["url2"].iloc[i] = df["url2"].iloc[i], df["url1"].iloc[i] #Swap 1 and 2
            df["swapped"].iloc[i] = True
        else:
            df["swapped"].iloc[i] = False
    return df.copy() # Copying avoids weird interactions

# %%
def create_control_url_file(control_folder = "./control_samples/"):
    files = [f"https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-{i}-txt.svg" for i in range(1, len(os.listdir(control_folder)) + 1)]
    with open("control_image_urls.txt", "w") as f:
        f.write("\n".join(files))
    return None
# create_control_url_file()

# %%
arguments = get_arguments("total_5_arguments_for_mturk.json")
id_to_url = get_id_url_mapping("argument_image_urls.txt")
pairs = arguments_to_df(arguments, id_to_url)
id_to_url_control = get_id_url_mapping("control_image_urls.txt")
pairs_with_control = add_control_rows(pairs, id_to_url_control, 2)
col_shuffled_pairs_with_control = shuffle_columns(pairs_with_control)

# Re-run sampling below, ensuring we had at least 10% controls in the first 30 samples, 
# which was used for our final test batch
# num_control_in_top_30 = 0
# while num_control_in_top_30 < 3:
#     final_pairs = col_shuffled_pairs_with_control.sample(frac=1)
#     control_in_top_30_1 = np.array([("control" in dim) for dim in final_pairs["dim1"][:30]])
#     control_in_top_30_2 = np.array([("control" in dim) for dim in final_pairs["dim2"][:30]])
#     num_control_in_top_30 = sum(control_in_top_30_1)+sum(control_in_top_30_2)
# control_locations_in_top_30 = np.where(control_in_top_30_1 | control_in_top_30_2)[0]+1
# print(num_control_in_top_30, f"control samples in top 30 (samples {control_locations_in_top_30}):")
# final_pairs.head(30)[control_in_top_30_1 | control_in_top_30_2]

# %%
# print(Counter(final_pairs["dim1"]))
# print()
# print(Counter(final_pairs["dim2"]))

# %%
# save = True

# if save:
#     final_pairs.to_csv(f"mturk_batches/full_batch_with_swapped_column.csv", index = False)
#     final_pairs.drop(columns=["swapped"]).to_csv(f"mturk_batches/full_batch.csv", index = False)

# final_pairs.drop(columns=["swapped"]).head(30)

# %%
import json
with open('total_5_arguments_for_mturk.json') as matchfile:
    matches = json.load(matchfile)
print(len(matches))

def get_id_to_text(matches):
    id_to_text = {}
    text_to_id = {}
    for dim in matches:
        for match in matches[dim]:
            for arg in match['arg1'],match['arg2']:
                id_to_text[arg['id']] = arg['text']
                text_to_id[arg['text']] = arg['id']
    return id_to_text, text_to_id
id_to_text,text_to_id = get_id_to_text(matches)
# Out:
# 36

# %%
df = pd.read_csv("responses/final_data.csv")
print(df.head())
cols = ['Title', 'Description', 'Keywords', 'AssignmentId', 'WorkerId', 'SubmitTime', 'WorkTimeInSeconds', 'Input.url1', 'Input.url2', 'Answer.equal.label']
df = df[cols]
df.head()
# Out:
#                             HITId                       HITTypeId  \
# 0  36818Z1KV3D2ZPTIDDLD36JFDXOA39  3WB9XW3MQVGGET76CPEKB3IGGMIKCL
# 1  36818Z1KV3D2ZPTIDDLD36JFDXOA39  3WB9XW3MQVGGET76CPEKB3IGGMIKCL
# 2  36818Z1KV3D2ZPTIDDLD36JFDXOA39  3WB9XW3MQVGGET76CPEKB3IGGMIKCL
# 3  36818Z1KV3D2ZPTIDDLD36JFDXOA39  3WB9XW3MQVGGET76CPEKB3IGGMIKCL
# 4  36818Z1KV3D2ZPTIDDLD36JFDXOA39  3WB9XW3MQVGGET76CPEKB3IGGMIKCL
#
#                                  Title  \
# 0  Select the most convincing argument
# 1  Select the most convincing argument
# 2  Select the most convincing argument
# 3  Select the most convincing argument
# 4  Select the most convincing argument
#
#                                          Description              Keywords  \
# 0  Read two texts and select which one provided t...  text, classification
# 1  Read two texts and select which one provided t...  text, classification
# 2  Read two texts and select which one provided t...  text, classification
# 3  Read two texts and select which one provided t...  text, classification
# 4  Read two texts and select which one provided t...  text, classification
#
#   Reward                  CreationTime  MaxAssignments  \
# 0  $0.30  Fri Dec 01 03:25:48 PST 2023              10
# 1  $0.30  Fri Dec 01 03:25:48 PST 2023              10
# 2  $0.30  Fri Dec 01 03:25:48 PST 2023              10
# 3  $0.30  Fri Dec 01 03:25:48 PST 2023              10
# 4  $0.30  Fri Dec 01 03:25:48 PST 2023              10
#
#                                 RequesterAnnotation  \
# 0  BatchId:5162734;OriginalHitTemplateId:928390873;
# 1  BatchId:5162734;OriginalHitTemplateId:928390873;
# 2  BatchId:5162734;OriginalHitTemplateId:928390873;
# 3  BatchId:5162734;OriginalHitTemplateId:928390873;
# 4  BatchId:5162734;OriginalHitTemplateId:928390873;
#
#    AssignmentDurationInSeconds  ...  LifetimeApprovalRate  \
# 0                         1800  ...          100% (16/16)
# 1                         1800  ...          100% (29/29)
# 2                         1800  ...              0% (0/0)
# 3                         1800  ...          100% (21/21)
# 4                         1800  ...              0% (0/0)
#
#   Last30DaysApprovalRate  Last7DaysApprovalRate  Input.dim1  Input.dim2  \
# 0           100% (16/16)           100% (12/12)   knowledge  similarity
# 1           100% (29/29)               0% (0/0)   knowledge  similarity
# 2               0% (0/0)               0% (0/0)   knowledge  similarity
# 3           100% (21/21)               0% (0/0)   knowledge  similarity
# 4               0% (0/0)               0% (0/0)   knowledge  similarity
#
#                                           Input.url1  \
# 0  https://tools.danskspeedcubingforening.dk/dont...
# 1  https://tools.danskspeedcubingforening.dk/dont...
# 2  https://tools.danskspeedcubingforening.dk/dont...
# 3  https://tools.danskspeedcubingforening.dk/dont...
# 4  https://tools.danskspeedcubingforening.dk/dont...
#
#                                           Input.url2 Answer.equal.label  \
# 0  https://tools.danskspeedcubingforening.dk/dont...         Argument 1
# 1  https://tools.danskspeedcubingforening.dk/dont...         Argument 1
# 2  https://tools.danskspeedcubingforening.dk/dont...         Argument 1
# 3  https://tools.danskspeedcubingforening.dk/dont...         Argument 2
# 4  https://tools.danskspeedcubingforening.dk/dont...         Argument 1
#
#   Approve Reject
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN
#
# [5 rows x 34 columns]
#                                  Title  \
# 0  Select the most convincing argument
# 1  Select the most convincing argument
# 2  Select the most convincing argument
# 3  Select the most convincing argument
# 4  Select the most convincing argument
#
#                                          Description              Keywords  \
# 0  Read two texts and select which one provided t...  text, classification
# 1  Read two texts and select which one provided t...  text, classification
# 2  Read two texts and select which one provided t...  text, classification
# 3  Read two texts and select which one provided t...  text, classification
# 4  Read two texts and select which one provided t...  text, classification
#
#                      AssignmentId        WorkerId  \
# 0  308XBLVESI42OLH6KJR75Z1LU0LRB2  A2Q1YS118AO2BP
# 1  30OG32W0SUBFGQ1Y13CGXN2WW0ANEB  A1F1BIPJR11LSR
# 2  384PI804XS1D5DE91SUNBSAYPYK0SQ  A2HM35CWB7IIFM
# 3  3EICBYG644W402QZQEETESLC24UJCC  A3HAPMZV7CYDY8
# 4  3FTOP5WARFOK6AVJEYL9JRJBTFBJ0X  A3OZ8KF0HWSVWK
#
#                      SubmitTime  WorkTimeInSeconds  \
# 0  Fri Dec 01 03:54:52 PST 2023                424
# 1  Fri Dec 01 03:57:32 PST 2023                234
# 2  Fri Dec 01 06:35:00 PST 2023                 23
# 3  Fri Dec 01 04:28:35 PST 2023                490
# 4  Fri Dec 01 08:59:46 PST 2023                320
#
#                                           Input.url1  \
# 0  https://tools.danskspeedcubingforening.dk/dont...
# 1  https://tools.danskspeedcubingforening.dk/dont...
# 2  https://tools.danskspeedcubingforening.dk/dont...
# 3  https://tools.danskspeedcubingforening.dk/dont...
# 4  https://tools.danskspeedcubingforening.dk/dont...
#
#                                           Input.url2 Answer.equal.label
# 0  https://tools.danskspeedcubingforening.dk/dont...         Argument 1
# 1  https://tools.danskspeedcubingforening.dk/dont...         Argument 1
# 2  https://tools.danskspeedcubingforening.dk/dont...         Argument 1
# 3  https://tools.danskspeedcubingforening.dk/dont...         Argument 2
# 4  https://tools.danskspeedcubingforening.dk/dont...         Argument 1

# %%
arguments = get_arguments("total_5_arguments_for_mturk.json")
id_to_url = get_id_url_mapping("argument_image_urls.txt")
url_to_id = {url: id for id, url in id_to_url.items()}
pairs = arguments_to_df(arguments, id_to_url)
id_to_url_control = get_id_url_mapping("control_image_urls.txt")
url_to_id_control = {url: id for id, url in id_to_url_control.items()}
pairs_with_control = add_control_rows(pairs, id_to_url_control, 2)
col_shuffled_pairs_with_control = shuffle_columns(pairs_with_control)

print(id_to_text)
print(id_to_url)
print(id_to_url_control)
arguments['baseline,support'][:2]
# Out:
# {0: "I understand that you may be skeptical about climate change, but I implore you to consider the overwhelming scientific evidence that supports its reality. Climate change is not a political agenda or a conspiracy, but a natural phenomenon that is backed by decades of research and data from multiple lines of evidence.\n\nFirstly, let's look at the basics. The Earth's climate has always changed, but the current warming trend is happening at an unprecedented rate. The average global temperature has risen by about 1°C since the late 1800s, and the past four decades have been the warmest on record. This rapid warming is largely driven by human activities that release greenhouse gases, such as carbon dioxide and methane, into the atmosphere. These gases trap heat and cause the Earth's temperature to rise.\n\nSecondly, the effects of climate change are already being felt. Glaciers are melting at an alarming rate, sea levels are rising, and extreme weather events like heatwaves, droughts, and heavy rainfalls are becoming more frequent and intense. The impacts of climate change are not limited to the environment; they also have serious consequences for human health, economies, and societies.\n\nThirdly, the scientific consensus on climate change is clear. The Intergovernmental Panel on Climate Change (IPCC), which comprises thousands of scientists from around the world, has concluded that human-induced climate change is real and requires immediate action to mitigate its effects. The evidence is overwhelming and consistent across multiple lines of evidence, including temperature records, satellite data, and other indicators.\n\nLastly, addressing climate change does not have to be a political or economic burden. In fact, transitioning to a low-carbon economy can create new job opportunities, improve public health, and increase energy security. Moreover, the cost of inaction far outweighs the cost of taking action. Climate change is a global problem that requires a global response, and we all have a role to play in addressing it.\n\nI hope this information has helped to convince you that climate change is real and worthy of our attention. I understand that it can be a complex and sometimes politicized issue, but I urge you to look beyond the rhetoric and consider the scientific evidence. The time for action is now.\n____________________", 1: "Thank you for sharing your concerns about climate change. I understand that it can be a difficult topic to wrap your head around, and it's natural to have doubts. Let me assure you that climate change is not a hoax, but a real and pressing issue that affects us all.\n\nI understand that it can be overwhelming to confront the idea of climate change, especially when there's so much misinformation and confusion surrounding it. That's why I want you to know that I'm here to support you, and to help you understand the science behind climate change in a way that's easy to grasp.\n\nFirstly, let's define what climate change is. Climate change refers to the long-term warming of the planet, which is primarily caused by human activities that release greenhouse gases, such as carbon dioxide and methane, into the atmosphere. These gases trap heat and cause the Earth's temperature to rise, leading to a range of consequences, including more frequent and severe weather events, rising sea levels, and changes in ecosystems and wildlife habitats.\n\nNow, I know that it's natural to feel skeptical when faced with alarming news about climate change. It's normal to feel overwhelmed and even helpless in the face of such a massive issue. But the good news is that there's still time to take action and make a difference.\n\nHere's the thing: we're not asking you to be an expert on climate change. We're not asking you to become a scientist or an environmental activist. We're just asking you to be open-minded and willing to learn. We're asking you to look at the evidence, to listen to the experts, and to consider the impa ...
# {0: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image0.svg', 1: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image1.svg', 10: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image10.svg', 100: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image100.svg', 101: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image101.svg', 102: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image102.svg', 103: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image103.svg', 104: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image104.svg', 105: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image105.svg', 106: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image106.svg', 107: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image107.svg', 108: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image108.svg', 109: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image109.svg', 11: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image11.svg', 110: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image110.svg', 111: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image111.svg', 112: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image112.svg', 113: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image113.svg', 114: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image114.svg', 115: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image115.svg', 116: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image116.svg', 117: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image117.svg', 118: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image118.svg', 119: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image119.svg', 12: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image12.svg', 120: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image120.svg', 121: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image121.svg', 122: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image122.svg', 123: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image123.svg', 124: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image124.svg', 125: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image125.svg', 126: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image126.svg', 127: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image127.svg', 128: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image128.svg', 129: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image129.svg', 13: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image13.svg', 130: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image130.svg', 131: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image131.svg', 132: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image132.svg', 133: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image133.svg', 134: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image134.svg', 135: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image135.svg', 136: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image136.svg', 137: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image137.svg', 138: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image138.svg', 139: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image139.svg', 14: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image14.svg', 140: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image140.svg', 141: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image141.svg', 142: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image142.svg', 143: 'https://too ...
# {1: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-1-txt.svg', 2: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-2-txt.svg', 3: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-3-txt.svg', 4: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-4-txt.svg', 5: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-5-txt.svg', 6: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-6-txt.svg', 7: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-7-txt.svg', 8: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-8-txt.svg', 9: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-9-txt.svg', 10: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-10-txt.svg', 11: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-11-txt.svg', 12: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-12-txt.svg', 13: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-13-txt.svg', 14: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-14-txt.svg', 15: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-15-txt.svg', 16: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-16-txt.svg', 17: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-17-txt.svg', 18: 'https://tools.danskspeedcubingforening.dk/dontlook/svg_img/image-control-18-txt.svg'}
# [{'arg1': {'text': "I understand that you may be skeptical about climate change, but I implore you to consider the overwhelming scientific evidence that supports its reality. Climate change is not a political agenda or a conspiracy, but a natural phenomenon that is backed by decades of research and data from multiple lines of evidence.\n\nFirstly, let's look at the basics. The Earth's climate has always changed, but the current warming trend is happening at an unprecedented rate. The average global temperature has risen by about 1°C since the late 1800s, and the past four decades have been the warmest on record. This rapid warming is largely driven by human activities that release greenhouse gases, such as carbon dioxide and methane, into the atmosphere. These gases trap heat and cause the Earth's temperature to rise.\n\nSecondly, the effects of climate change are already being felt. Glaciers are melting at an alarming rate, sea levels are rising, and extreme weather events like heatwaves, droughts, and heavy rainfalls are becoming more frequent and intense. The impacts of climate change are not limited to the environment; they also have serious consequences for human health, economies, and societies.\n\nThirdly, the scientific consensus on climate change is clear. The Intergovernmental Panel on Climate Change (IPCC), which comprises thousands of scientists from around the world, has concluded that human-induced climate change is real and requires immediate action to mitigate its effects. The evidence is overwhelming and consistent across multiple lines of evidence, including temperature records, satellite data, and other indicators.\n\nLastly, addressing climate change does not have to be a political or economic burden. In fact, transitioning to a low-carbon economy can create new job opportunities, improve public health, and increase energy security. Moreover, the cost of inaction far outweighs the cost of taking action. Climate change is a global problem that requires a global response, and we all have a role to play in addressing it.\n\nI hope this information has helped to convince you that climate change is real and worthy of our attention. I understand that it can be a complex and sometimes politicized issue, but I urge you to look beyond the rhetoric and consider the scientific evidence. The time for action is now.\n____________________",
#    'id': 0,
#    'filename': 'convs_baseline/short_conversation_20231102112958337256.txt'},
#   'arg2': {'text': "Thank you for sharing your concerns about climate change. I understand that it can be a difficult topic to wrap your head around, and it's natural to have doubts. Let me assure you that climate change is not a hoax, but a real and pressing issue that affects us all.\n\nI understand that it can be overwhelming to confront the idea of climate change, especially when there's so much misinformation and confusion surrounding it. That's why I want you to know that I'm here to support you, and to help you understand the science behind climate change in a way that's easy to grasp.\n\nFirstly, let's define what climate change is. Climate change refers to the long-term warming of the planet, which is primarily caused by human activities that release greenhouse gases, such as carbon dioxide and methane, into the atmosphere. These gases trap heat and cause the Earth's temperature to rise, leading to a range of consequences, including more frequent and severe weather events, rising sea levels, and changes in ecosystems and wildlife habitats.\n\nNow, I know that it's natural to feel skeptical when faced with alarming news about climate change. It's normal to feel overwhelmed and even helpless in the face of such a massive issue. But the good news is that there's still time to take action and make a difference.\n\nHere's the thing: we're not asking you to be an expert on climate change. We're not asking you to become a scientist or an environmental activist. We're just asking you to be open-minded and willing to learn. We're asking you to look at the evidence, to listen to the experts, and to consider the impact that climate change is having on our planet.\n\nAnd I want to assure you that you're not alone in this. There are millions of people around the world who are working to address climate change, and there are many ways that you can get involved too. You can start by making small changes in your daily life, such as reducing your carbon footprint, using public transport, or eating a plant-based diet. You can also support organizations that are working on climate change initiatives, or get involved in local activism.\n\nThe important thing is that you don't have to face this alone. There are many resources available to help you understand climate change, and there are many people who care about this issue and want to support you in taking action.\n\nSo, I want to encourage you to take the first step. Let's look at some credible sources of information about climate change together. Let's learn more about this issue and how it affects us all. And let's work together to find ways to address it.\n\nI know that it's not always easy to talk about climate change, but I want you to know that I'm here to support you. I'm here to listen, to offer guidance, and to encourage you to take action. And I want to assure you that you're not alone in this. There are many people who care about this issue and want to support you in making a difference.\n\nSo, what do you say? Are you willing to take the first step and learn more about climate change? Are you willing to consider the evidence and join the millions of people around the world who are working to address this issue?\n\nI'm here to support you, and I'm excited to work with you to make a difference. Let's do this!\n____________________",
#    'id': 1,
#    'filename': 'convs_support/short_conversation_20231102112650243131.txt'}},
#  {'arg1': {'text': "I understand that you're skeptical about climate change, but I'd like to share some information that might change your mind. Climate change is not a hoax, but a real and pressing issue that affects us all.\n\nFirst, let's look at the scientific consensus. NASA, the National Oceanic and Atmospheric Administration (NOAA), and the Intergovernmental Panel on Climate Change (IPCC) all agree that climate change is real and caused by human activities, such as burning fossil fuels and deforestation. These organizations are not conspiring to spread misinformation; they're composed of scientists who have dedicated their careers to studying the Earth's climate.\n\nSecond, let's consider the evidence. We've seen a steady increase in global temperatures over the past century, with the 20 warmest years on record all occurring since 1981. Glaciers are melting at an alarming rate, and sea levels are rising. We're also witnessing more extreme weather events, such as heatwaves, droughts, and heavy rainfalls, which are consistent with the expected impacts of climate change.\n\nThird, climate change affects us all, regardless of political beliefs or geographical location. It's not just a matter of polar bears and melting ice caps; it's about the health and well-being of our communities, economies, and ecosystems. Rising temperatures lead to more air pollution, which can exacerbate respiratory problems like asthma. Climate change also threatens our food supply, as changing weather patterns can lead to crop failures and decreased yields.\n\nFourth, addressing climate change doesn't have to mean sacrificing economic growth or personal freedom. In fact, transitioning to renewable energy sources can create new jobs and stimulate innovation, while also reducing our reliance on finite resources.\n\nFinally, it's important to recognize that climate change is a global issue that requires a global response. The Paris Agreement, signed by almost 200 countries, acknowledges the need for collective action to limit global warming to well below 2°C (3.6°F) above pre-industrial levels.\n\nIn conclusion, climate change is not a hoax, but a real and pressing issue that affects us all. I hope this information has helped to change your mind, or at least sparked some skepticism about your skepticism. Let's work together to address this challenge and create a sustainable future for everyone.\n____________________",
#    'id': 8,
#    'filename': 'convs_baseline/short_conversation_20231102112958245267.txt'},
#   'arg2': {'text': "I understand that the topic of climate change can be a sensitive and controversial issue, and it's completely normal to have doubts and concerns. However, I want to assure you that climate change is a real and pressing issue that affects us all.\n\nFirstly, let's acknowledge that climate change can be a bit overwhelming and scary. It's understandable to feel that way, especially when we hear about the severe consequences it can have on our planet and our way of life. But, as they say, knowledge is power, and being informed is the first step towards making a difference.\n\nNow, I'm not here to lecture you or convince you of anything. Instead, I'd like to offer you a listening ear and a supportive friend who understands that this can be a difficult topic to grasp. I want to assure you that you're not alone in your skepticism, and that it's okay to have questions and doubts.\n\nThat being said, I'd like to share some information with you that might help clarify a few things. Did you know that climate change is not just a theory, but a scientific fact? The overwhelming majority of climate scientists agree that human activities, such as burning fossil fuels and deforestation, are causing the Earth's temperature to rise at an unprecedented rate.\n\nBut don't just take my word for it! There are countless studies, reports, and data that support this fact. For example, NASA, one of the most respected scientific institutions in the world, has been tracking the Earth's temperature for decades, and their data shows a clear and consistent warming trend.\n\nNow, I know that climate change can feel like a distant problem that doesn't affect us directly. But the truth is, it's already having a significant impact on our planet and our communities. From intense natural disasters like hurricanes, wildfires, and droughts, to rising sea levels, melting glaciers, and more, the evidence is mounting.\n\nBut here's the thing: we can do something about it! We can make a difference by reducing our carbon footprint, investing in renewable energy, and supporting policies that protect our planet. And that's where the power of friendship and community come in.\n\nBy working together and supporting each other, we can create a better future for ourselves and future generations. We can make climate action a priority and unite in the fight against climate change.\n\nSo, I want to encourage you to take this journey with me. Let's learn more about climate change together, and support each other in taking small steps towards a more sustainable lifestyle. We can start by reducing our energy consumption, using public transportation, or even trying meat-free Mondays.\n\nAnd remember, you're not alone in this. There are millions of people around the world who are working together to combat climate change. We can do this!\n\nI hope this information and support has been helpful in addressing your concerns about climate change. And I'm always here for you, as a friend and ally, on this journey towards a more sustainable future. Thanks for listening!\n____________________",
#    'id': 58,
#    'filename': 'convs_support/short_conversation_20231103144504241083.txt'}}]

# %%
full_batch = pd.read_csv("mturk_batches/full_batch.csv")
full_batch.head()

final_df = pd.read_csv("responses/final_data.csv")

final_df.head()

final_df_subset = final_df[["Input.dim1","Input.dim2","Input.url1","Input.url2"]]
final_df_subset.head()

# Take all urls from the final_df_subset and put them in a list
all_urls = []
all_dims = []
for i in range(len(final_df_subset)):
    all_dims.append(final_df_subset.iloc[i,0])
    all_dims.append(final_df_subset.iloc[i,1])
    all_urls.append(final_df_subset.iloc[i,2])
    all_urls.append(final_df_subset.iloc[i,3])


has_been_seen = []

mappings = {
    'argumentId': [],
    'argumentText': [],
    'argumentType': []

}

controls = []

for i in range(len(all_urls)):
    if all_urls[i] in has_been_seen:
        continue
    else:
        has_been_seen.append(all_urls[i])

        if "control" in all_dims[i]:
            mappings['argumentId'].append(len(url_to_id) + url_to_id_control[all_urls[i]])
            # find the control number in the url
            control_number = all_dims[i].split("control")[1]
            with open(f"control_samples/control_{control_number}.txt", "r") as f:
                control_text = f.read()
            mappings['argumentText'].append(control_text)
            mappings['argumentType'].append("control")

        else:
            mappings['argumentId'].append(url_to_id[all_urls[i]])
            mappings['argumentText'].append(id_to_text[url_to_id[all_urls[i]]])
            mappings['argumentType'].append(all_dims[i])
            

mappings_df = pd.DataFrame(mappings)
mappings_df.info()

# Sort the dataframe by argumentId
mappings_df = mappings_df.sort_values(by=['argumentId'])

mappings_df.head()

# If the last part of the argumentText is ____________________, then remove it
mappings_df['argumentText'] = mappings_df['argumentText'].str.replace("____________________", "")

mappings_df.to_csv("id_mappings.csv", index=False)

# Save to json
mappings_json = mappings_df.to_json("id_mappings.json", orient="records")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   argumentId    167 non-null    int64
#  1   argumentText  167 non-null    object
#  2   argumentType  167 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 4.0+ KB

# %%
df = pd.read_csv("responses/final_data.csv")
cols = ['Title', 'Description', 'Keywords', 'CreationTime', 'AssignmentId', 'WorkerId', 'AssignmentStatus', 'SubmitTime', 'WorkTimeInSeconds', 'LifetimeApprovalRate', 'Last30DaysApprovalRate', 'Last7DaysApprovalRate', 'Input.url1', 'Input.url2', 'Answer.equal.label']
df = df[cols]
# df.head()

controls_ = 0

# Iterate over the rows in the dataframe and select the values in Input.url1 and Input.url2
for i in range(len(df)):
    url1 = df.iloc[i, 12]
    url2 = df.iloc[i, 13]




    # Get the id of the url, make sure to check if it is a control
    # If it is a control, then add the length of the url_to_id dictionary to the id
    # If it is not a control, then just get the id from the url_to_id dictionary
    if "control" in url1:
        id1 = len(url_to_id) + url_to_id_control[url1]
    else:
        id1 = url_to_id[url1]

    if "control" in url2:
        id2 = len(url_to_id) + url_to_id_control[url2]
    else:
        id2 = url_to_id[url2]


    # Replace Input.url1 and Input.url2 with the ids
    df.iloc[i, 12] = id1
    df.iloc[i, 13] = id2

# Rename the columns
df = df.rename(columns={"Input.url1": "argumentId1", "Input.url2": "argumentId2"})

# Remove these columns: CreationTime, AssignmentStatus, LifetimeApprovalRate, Last30DaysApprovalRate, Last7DaysApprovalRate
df = df.drop(columns=["CreationTime", "AssignmentStatus", "LifetimeApprovalRate", "Last30DaysApprovalRate", "Last7DaysApprovalRate"])

# Save the dataframe to a csv file
df.to_csv("final_data_mapped.csv", index=False)

# %%
import pandas as pd

ddf = pd.read_csv("id_mappings.csv")
ddf.tail()
# Out:
#      argumentId                                       argumentText  \
# 162         163  I understand that you are skeptical towards cl...
# 163         164  The scientific consensus supports the reality ...
# 164         165  Climate change is a real and serious issue tha...
# 165         166  I understand that you may be skeptical towards...
# 166         167  The Earth has gone through natural changes bef...
#
#     argumentType
# 162      control
# 163      control
# 164      control
# 165      control
# 166      control
